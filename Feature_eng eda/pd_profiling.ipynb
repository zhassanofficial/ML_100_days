# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
from ydata_profiling import ProfileReport

# %%
prof = ProfileReport(df)

# %%
prof.to_file('my_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 89.22it/s]<00:00, 35.63it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:04<00:00, 11.18it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:06<00:00,  6.90s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 39.89it/s]
