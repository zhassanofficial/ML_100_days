# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('play_tennis.csv')
df.head()
df.drop(columns='day' , inplace=True)

# %%
df.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %%
df.shape
# Out:
# (14, 5)

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py = 9/14
pn = 5/14

# %%
print(py)
print(pn)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %% [markdown]
# probability for outlook column

# %%
pd.crosstab(df['outlook'] , df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
Poulookn = 0/5
Prrainn = 2/5
Pssunnyn = 3/5

Poutlooky = 4/9
Prainy =3/9
Psunnyy = 2/9

# %% [markdown]
# probability for temperature column

# %%
pd.crosstab(df['temp'] ,df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
Pcoolno = 1/5
Photno = 2/5
Pmildno = 2/5


Pcoolyes = 3/9
photyes = 2/9
Pmildyes = 4/9

# %% [markdown]
# probability for humidity column

# %%
pd.crosstab(df['humidity'] ,df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
Phighno = 4/5
Pnormalno = 1/5

Phighyes = 3/9
pnormalyes = 6/9

# %% [markdown]
# probability for wind column

# %%
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
Pstrongno = 3/5
Pweakno = 2/5

Pstrongyes = 3/9
Pweakyes = 6/9

# %% [markdown]
# problem no 1
# outlook = sunny , temp = hot , humidity = high , wind = weak
# find probality of plyaing match for this problem

# %%
Pyes = py*Psunnyy*photyes*Phighyes*Pweakyes

# %%
Pyes
# Out:
# 0.007054673721340388

# %%
Pno = pn*Pssunnyn*Photno*Phighno*Pweakno

# %%
Pno
# Out:
# 0.02742857142857143

# %% [markdown]
# as Pno > Pyes so no game wil be played on this day
