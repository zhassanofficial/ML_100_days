# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_emark = pickle.load(open('models/ohe_emark.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
test_input = np.array([2,'male',25,0,1,13,'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 25, 0, 1, 13, 'S']], dtype=object)

# %%
test_input_sex =ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# c:\Users\zhass\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex.shape
# Out:
# (1, 2)

# %%
test_input_embark = ohe_emark.transform(test_input[:,-1].reshape(1,1))
# Out:
# c:\Users\zhass\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_embark
# Out:
# array([[0., 0., 1., 0.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_age.shape
# Out:
# (1, 1)

# %%
test_input
# Out:
# array([[2, 'male', 25, 0, 1, 13, 'S']], dtype=object)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_sex,test_input_age,test_input_embark),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 11)

# %%
clf.n_features_in_
# Out:
# 11

# %%
pred = clf.predict(test_input_transformed)
