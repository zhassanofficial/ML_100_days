# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('Pipe.pkl','rb'))

# %%
test_input = np.array([1,'male',25,0,0,14,'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# c:\Users\zhass\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\zhass\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
